# %% [markdown]
# ---
# description: action list
# output-file: actions.html
# title: actions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(_Action)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/actions.py#L896){target="_blank" style="float:right; font-size:smaller"}
#
# ### _Action
#
# >      _Action (app, action_key:str, pset_key=None)
#
# 한글 Action 클래스 입니다. 엑션의 기능을 사용하기 쉽게 만들고자 했습니다.

# %%
#| echo: false
#| output: asis
show_doc(create_action_wrapper)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/actions.py#L937){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_action_wrapper
#
# >      create_action_wrapper (app, action_key, pset_key=None)

# %%
#| echo: false
#| output: asis
show_doc(_Actions)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/actions.py#L943){target="_blank" style="float:right; font-size:smaller"}
#
# ### _Actions
#
# >      _Actions (app)
#
# 사전에 정보가 확인된 Action들을 App에 등록하는 기능을 합니다.
