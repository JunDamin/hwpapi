# %% [raw]
# ---
# description: Core Classes for hwpapi
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(App)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### App
#
# >      App (api=None, is_visible=True)
#
# App 클래스는 한컴오피스의 한/글 프로그램과 상호작용하기 위한 인터페이스를 제공합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.reload)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L51){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.reload
#
# >      App.reload (app:__main__.App)

# %%
#| echo: false
#| output: asis
show_doc(App.set_visible)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L59){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.set_visible
#
# >      App.set_visible (app:__main__.App, is_visible=True, window_i=0)
#
# `set_visible()` 함수는 한/글 프로그램의 창을 화면에 보이거나 숨기기 위해 호출됩니다.
# `is_visible` 인자가 `True`일 경우 창이 화면에 보이고, `False`일 경우 숨깁니다.
# `window_i` 인자는 창의 인덱스를 지정합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.get_filepath)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L68){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.get_filepath
#
# >      App.get_filepath (app:__main__.App)
#
# `get_filepath()` 함수는 현재 열려있는 한/글 문서의 경로를 반환합니다.

# %%
import pywintypes

try:
    app = App(app.api)
except NameError:
    app = App()
except pywintypes.com_error:
    app = App()
# Out:
# Rebuilding cache of generated files for COM support...
# Checking 7D2B6F3C-1D95-4E0C-BF5A-5EE564186FBCx0x1x0
# Could not add module (IID('{7D2B6F3C-1D95-4E0C-BF5A-5EE564186FBC}'), 0, 1, 0) - <class 'ImportError'>: cannot import name 'Dispatch' from partially initialized module 'win32com.client' (most likely due to a circular import) (C:\Users\freed\AppData\Roaming\Python\Python310\site-packages\win32com\client\__init__.py)
# Done.

# %%
#| echo: false
#| output: asis
show_doc(App.open)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L75){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.open
#
# >      App.open (app:__main__.App, path:str)
#
# `open()` 함수는 파일 경로를 인자로 받아 해당 파일을 한/글 프로그램에서 엽니다.
# `get_absolute_path()` 함수를 호출하여 절대 경로로 변환한 후, `api.Open()` 함수를 호출하여 파일을 엽니다.
# 열린 파일의 경로를 반환합니다.

# %%
app.open("test/공문양식.hwp")
# Out:
# 'C:/Users/freed/Documents/python_projects/hwpapi/nbs/02_api/test/공문양식.hwp'

# %%
#| echo: false
#| output: asis
show_doc(App.save)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L85){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.save
#
# >      App.save (app:__main__.App, path=None)
#
# `save()` 함수는 현재 열려있는 문서를 저장하거나 다른 이름으로 저장합니다.
# `path` 인자가 주어지지 않은 경우 현재 문서를 덮어쓰기로 저장하고, 저장된 파일의 경로를 반환합니다.
# `path` 인자가 주어진 경우, `Path` 모듈을 이용하여 파일 확장자를 추출한 후, 해당 확장자에 맞게 문서를 저장합니다.
# 저장된 파일의 경로를 반환합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.close)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L108){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.close
#
# >      App.close (app:__main__.App)
#
# `close()` 함수는 현재 열려있는 문서를 닫습니다.

# %%
#| echo: false
#| output: asis
show_doc(App.quit)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L114){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.quit
#
# >      App.quit (app:__main__.App)
#
# `quit()` 함수는 한/글 프로그램을 종료합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.create_action)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L120){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.create_action
#
# >      App.create_action (app:__main__.App, action_key:str)
#
# `create_action()` 함수는 `_Action` 클래스의 객체를 생성하여 반환합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.create_parameterset)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L126){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.create_parameterset
#
# >      App.create_parameterset (app:__main__.App, action_key:str)
#
# `create_parameterset()` 함수는 특정 액션의 파라미터셋을 반환합니다.
# `_action_info` 딕셔너리에서 액션에 대한 정보를 찾아서 파라미터셋의 키 값을 가져옵니다. 파라미터셋 객체를 반환합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.get_charshape)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L136){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.get_charshape
#
# >      App.get_charshape (app:__main__.App)

# %%
app.get_charshape()
# Out:
# {'Bold': 0,
#  'DiacSymMark': 0,
#  'Emboss': 0,
#  'Engrave': 0,
#  'FaceNameHangul': '함초롬바탕',
#  'FaceNameHanja': '함초롬바탕',
#  'FaceNameJapanese': '함초롬바탕',
#  'FaceNameLatin': '함초롬바탕',
#  'FaceNameOther': '함초롬바탕',
#  'FaceNameSymbol': '함초롬바탕',
#  'FaceNameUser': '함초롬바탕',
#  'FontTypeHangul': 1,
#  'FontTypeHanja': 1,
#  'FontTypeJapanese': 1,
#  'FontTypeLatin': 1,
#  'FontTypeOther': 1,
#  'FontTypeSymbol': 1,
#  'FontTypeUser': 1,
#  'Height': 1000,
#  'Italic': 0,
#  'OffsetHangul': 0,
#  'OffsetHanja': 0,
#  'OffsetJapanese': 0,
#  'OffsetLatin': 0,
#  'OffsetOther': 0,
#  'OffsetSymbol': 0,
#  'OffsetUser': 0,
#  'OutLineType': 0,
#  'RatioHangul': 100,
#  'RatioHanja': 100,
#  'RatioJapanese': 100,
#  'RatioLatin': 100,
#  'RatioOther': 100,
#  'RatioSymbol': 100,
#  'RatioUser': 100,
#  'ShadeColor': 4294967295,
#  'ShadowColor': 12632256,
#  'ShadowOffsetX': 10,
#  'ShadowOffsetY': 10,
#  'ShadowType': 0,
#  'SizeHangul': 100,
#  'SizeHanja': 100,
#  'SizeJapanese': 100,
#  'SizeLatin': 100,
#  'SizeOther': 100,
#  'SizeSymbol': 100,
#  'SizeUser': 100,
#  'SmallCaps': 0,
#  'SpacingHangul': 0,
#  'SpacingHanja': 0,
#  'SpacingJapanese': 0,
#  'SpacingLatin': 0,
#  'SpacingOther': 0,
#  'SpacingSymbol': 0,
#  'SpacingUser': 0,
#  'StrikeOutColor': 0,
#  'StrikeOutShape': 0,
#  'StrikeOutType': 0,
#  'SubScript': 0,
#  'SuperScript': 0,
#  'TextColor': 0,
#  'UnderlineColor': 0,
#  'UnderlineShape': 0,
#  'UnderlineType': 0,
#  'UseFontSpace': 0,
#  'UseKerning': 0}

# %%
#| echo: false
#| output: asis
show_doc(App.set_charshape)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L213){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.set_charshape
#
# >      App.set_charshape (app:__main__.App, fontname:str=None, font_type:int=1,
# >                         size:int=None, ratio:int=None, spacing:int=None,
# >                         offset:int=None, bold:bool=None, italic:bool=None,
# >                         small_caps:bool=None, emboss:bool=None,
# >                         super_script:bool=None, sub_script:bool=None,
# >                         underline_type:int=None, outline_type:int=None,
# >                         text_color=None, shade_color=None,
# >                         underline_shape:int=None, underline_color=None,
# >                         shadow_offset_x:int=None, shadow_offset_y:int=None,
# >                         shadow_color=None, strike_out_type=None,
# >                         diac_sym_mark=None, use_font_space=None,
# >                         use_kerning=None, height:int=None)
#
# `현재 위치의 글자 모양을 조정합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.get_parashape)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L288){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.get_parashape
#
# >      App.get_parashape (app:__main__.App)

# %%
app.get_parashape()
# Out:
# {'AlignType': 0,
#  'AutoSpaceEAsianEng': 0,
#  'AutoSpaceEAsianNum': 0,
#  'BorderConnect': 0,
#  'BorderOffsetBottom': 0,
#  'BorderOffsetLeft': 0,
#  'BorderOffsetRight': 0,
#  'BorderOffsetTop': 0,
#  'BorderText': 0,
#  'BreakLatinWord': 0,
#  'BreakNonLatinWord': 1,
#  'Checked': 0,
#  'Condense': 0,
#  'FontLineHeight': 0,
#  'HeadingType': 0,
#  'Indentation': 0,
#  'KeepLinesTogether': 0,
#  'KeepWithNext': 0,
#  'LeftMargin': 0,
#  'Level': 0,
#  'LineSpacing': 160,
#  'LineSpacingType': 0,
#  'LineWrap': 0,
#  'NextSpacing': 0,
#  'PagebreakBefore': 0,
#  'PrevSpacing': 0,
#  'RightMargin': 0,
#  'SnapToGrid': 1,
#  'SuppressLineNum': 0,
#  'TailType': 0,
#  'TextAlignment': 0,
#  'WidowOrphan': 0}

# %%
#| echo: false
#| output: asis
show_doc(App.set_parashape)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L331){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.set_parashape
#
# >      App.set_parashape (app:__main__.App, left_margin:int=None,
# >                         right_margin:int=None, indentation:int=None,
# >                         prev_spacing:int=None, next_spacing:int=None,
# >                         line_spacing_type:str=None, line_spacing:int=None,
# >                         align_type:str=None, break_latin_word:str=None,
# >                         break_non_latin_word:bool=None,
# >                         snap_to_grid:bool=None, condense:float=None,
# >                         widow_orphan:bool=None, keep_with_next:bool=None,
# >                         page_break_before:bool=None, text_alignment:str=None,
# >                         font_line_height:int=None, heading_type:str=None,
# >                         level:int=None, border_connect:bool=None,
# >                         border_text:bool=None, border_offset_left:int=None,
# >                         border_offset_right:int=None,
# >                         border_offset_top:int=None,
# >                         border_offset_bottom:int=None, tail_type:bool=None,
# >                         line_wrap:bool=None, tab_def=None, numbering=None,
# >                         bullet=None, borderfill=None)

# %%
#| echo: false
#| output: asis
show_doc(App.insert_text)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L469){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.insert_text
#
# >      App.insert_text (app:__main__.App, text:str, fontname=None, font_type=1,
# >                       bold=None, italic=None, strike_out_type=None,
# >                       underline_type=None, ratio=None, height=None,
# >                       text_color=None)
#
# `text를 입력합니다.

# %%
app.insert_text("안녕하세요", fontname="돋움체", ratio=90, height=11, text_color="#1FBCAA")

# %%
app.set_parashape(right_margin=20, align_type="Left")
# Out:
# True

# %%
parashape = app.actions.ParagraphShape()

# %%
parashape.pset.RightMargin
# Out:
# 4000

# %%
#| echo: false
#| output: asis
show_doc(App.scan)
# Out:
# ---
#
# ### scan
#
# >      scan (app:__main__.App, option='All', selection=False,
# >            scan_spos='Document', scan_epos='Document', spara=None, spos=None,
# >            epara=None, epos=None, scan_direction='Forward')

# %%
#| echo: false
#| output: asis
show_doc(move_to_line)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L582){target="_blank" style="float:right; font-size:smaller"}
#
# ### move_to_line
#
# >      move_to_line (app:__main__.App, text)
#
# 인자로 전달한 텍스트가 있는 줄의 시작지점으로 이동합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.move)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L634){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.move
#
# >      App.move (app:__main__.App, key='ScanPos', para=None, pos=None)
#
# 키워드를 바탕으로 캐럿 위치를 이동시킵니다.

# %%
get_value(move_ids, "ScanPos")
# Out:
# 201

# %%
@patch
def setup_page(
    app: App,  # app
    top=20,  # 윗 여백
    bottom=10,  # 아래 여백
    right=20,  # 오른쪽 여백
    left=20,  # 왼쪽 여백
    header=15,  # 머릿말
    footer=5,  # 꼬릿말
    gutter=0,
):  # 제본
    """
    페이지를 설정합니다.
    """
    action = app.actions.PageSetup()
    p = action.pset

    p.PageDef.TopMargin = app.api.MiliToHwpUnit(top)
    p.PageDef.HeaderLen = app.api.MiliToHwpUnit(header)
    p.PageDef.RightMargin = app.api.MiliToHwpUnit(right)
    p.PageDef.BottomMargin = app.api.MiliToHwpUnit(bottom)
    p.PageDef.FooterLen = app.api.MiliToHwpUnit(footer)
    p.PageDef.LeftMargin = app.api.MiliToHwpUnit(left)
    p.PageDef.GutterLen = app.api.MiliToHwpUnit(gutter)

    return action.run()

# %%
#| echo: false
#| output: asis
show_doc(App.insert_picture)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L656){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.insert_picture
#
# >      App.insert_picture (app:__main__.App, fpath, width=None, height=None,
# >                          size_option='realSize', reverse=False,
# >                          watermark=False, effect='RealPicture')
#
# 사이즈를 지정하여 사진 삽입
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | app | App |  | app |
# | fpath |  |  | 그림 위치 |
# | width | NoneType | None | 넓이 |
# | height | NoneType | None | 높이 |
# | size_option | str | realSize | 사이즈 옵션 |
# | reverse | bool | False | 이미지 반전 여부 |
# | watermark | bool | False | 워커마크 여부 |
# | effect | str | RealPicture | 화면 효과 |

# %%
#| echo: false
#| output: asis
show_doc(App.select_text)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L684){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.select_text
#
# >      App.select_text (app:__main__.App, option:str='Line')
#
# 한줄을 선택합니다.

# %%
app.select_text()
# Out:
# (True, True)

# %%
app.set_charshape(fontname="바탕", height=20)
# Out:
# True

# %%
#| echo: false
#| output: asis
show_doc(App.get_selected_text)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L699){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.get_selected_text
#
# >      App.get_selected_text (app:__main__.App)
#
# 선택된 영역의 텍스트를 불러온다.

# %%
app.get_selected_text()
# Out:
# '  제 목 : OOOO안녕하세요\n'

# %%
#| echo: false
#| output: asis
show_doc(App.get_text)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L709){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.get_text
#
# >      App.get_text (app:__main__.App, spos='Line', epos='Line')
#
# 텍스트를 가져옵니다. 기본은 현재 문장입니다.

# %%
app.get_text()
# Out:
# '  제 목 : OOOO안녕하세요\r\n'

# %%
#| echo: false
#| output: asis
show_doc(App.find_text)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L722){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.find_text
#
# >      App.find_text (app:__main__.App, text='', text_fontcolor=None,
# >                     fontsize=None, fontname='', fonttype=1, fontratio=None,
# >                     text_color=None, spacing=None, bold=None, italic=None,
# >                     underline=None, strike_out=None, ignore_message=True,
# >                     direction='Forward', match_case=False,
# >                     all_word_forms=False, several_words=False,
# >                     use_wild_cards=False, whole_word_only=False,
# >                     replace_mode=False, ignore_find_string=False,
# >                     ignore_replace_string=False, find_style='',
# >                     replace_style='', find_jaso=False, find_reg_exp=False,
# >                     find_type=False)
#
# text를 찾습니다.
# 찾지못하면 False를 반환합니다.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | app | App |  |  |
# | text | str |  |  |
# | text_fontcolor | NoneType | None | 찾을 폰트 색 |
# | fontsize | NoneType | None | 찾을 폰트 크기(height) |
# | fontname | str |  | 찾을 글꼴 |
# | fonttype | int | 1 | 찾을 글꼴 타입 TTF = 1, HTF = 2 |
# | fontratio | NoneType | None | 찾을 장평 |
# | text_color | NoneType | None |  |
# | spacing | NoneType | None | 찾을 자간 |
# | bold | NoneType | None | 찾을 볼드 |
# | italic | NoneType | None | 찾을 이텔릭 |
# | underline | NoneType | None | 찾을 밑줄 |
# | strike_out | NoneType | None | 찾을 취소선 |
# | ignore_message | bool | True | 메시지 무시 여부 |
# | direction | str | Forward | 찾을 방향 |
# | match_case | bool | False | 대소문자 구분 |
# | all_word_forms | bool | False | 문자열 결합 |
# | several_words | bool | False | 여러 단어 찾기 |
# | use_wild_cards | bool | False | 아무개 문자 |
# | whole_word_only | bool | False | 온전한 낱말 |
# | replace_mode | bool | False | 찾아 바꾸기 모드 |
# | ignore_find_string | bool | False | 찾을 문자열 무시 |
# | ignore_replace_string | bool | False | 바꿀 문자열 무시 |
# | find_style | str |  | 찾을 스타일 |
# | replace_style | str |  |  |
# | find_jaso | bool | False | 자소로 찾기 |
# | find_reg_exp | bool | False | 정규표현식으로 찾기 |
# | find_type | bool | False | 다시 찾기를 할 때 마지막으로 실한 찾기를 할 경우 True, 찾아가기를 할경우 False |

# %%
app.find_text("안녕하세요")
# Out:
# True

# %%
#| echo: false
#| output: asis
show_doc(App.replace_all)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L796){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.replace_all
#
# >      App.replace_all (app:__main__.App, old='', new='', old_text_color=None,
# >                       new_text_color=None, old_fontsize=None,
# >                       new_fontsize=None, old_fontname='', old_fonttype=1,
# >                       new_fontname='', new_fonttype=1, old_fontratio=None,
# >                       new_fontratio=None, old_spacing=None, new_spacing=None,
# >                       old_bold=None, new_bold=None, old_italic=None,
# >                       new_italic=None, old_underline=None, new_underline=None,
# >                       old_strike_out=None, new_strike_out=None,
# >                       ignore_message=True, direction='All', match_case=False,
# >                       all_word_forms=False, several_words=False,
# >                       use_wild_cards=False, whole_word_only=False,
# >                       auto_spell=True, replace_mode=True,
# >                       ignore_find_string=False, ignore_replace_string=False,
# >                       find_style='', replace_style='', find_jaso=False,
# >                       find_reg_exp=False, find_type=True)
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | app | App |  |  |
# | old | str |  |  |
# | new | str |  |  |
# | old_text_color | NoneType | None | 찾을 폰트 색 |
# | new_text_color | NoneType | None | 바꿀 폰트 색 |
# | old_fontsize | NoneType | None | 찾을 폰트 크기(height) |
# | new_fontsize | NoneType | None | 바꿀 폰트 크기(height) |
# | old_fontname | str |  | 찾을 글꼴 |
# | old_fonttype | int | 1 | 찾을 글꼴 타입 TTF = 1, HTF = 2 |
# | new_fontname | str |  | 바꿀 글꼴 |
# | new_fonttype | int | 1 | 바꿀 글꼴 타입 TTF = 1, HTF = 2 |
# | old_fontratio | NoneType | None | 찾을 장평 |
# | new_fontratio | NoneType | None | 바꿀 장평 |
# | old_spacing | NoneType | None | 찾을 자간 |
# | new_spacing | NoneType | None | 바꿀 자간 |
# | old_bold | NoneType | None | 찾을 볼드 |
# | new_bold | NoneType | None | 바꿀 볼드 |
# | old_italic | NoneType | None | 찾을 이텔릭 |
# | new_italic | NoneType | None | 바꿀 이텔릭 |
# | old_underline | NoneType | None | 찾을 밑줄 |
# | new_underline | NoneType | None | 바꿀 밑줄 |
# | old_strike_out | NoneType | None | 찾을 취소선 |
# | new_strike_out | NoneType | None | 바꿀 취소선 |
# | ignore_message | bool | True | 메시지 무시 여부 |
# | direction | str | All | 찾을 방향 |
# | match_case | bool | False | 대소문자 구분 |
# | all_word_forms | bool | False | 문자열 결합 |
# | several_words | bool | False | 여러 단어 찾기 |
# | use_wild_cards | bool | False | 아무개 문자 |
# | whole_word_only | bool | False | 온전한 낱말 |
# | auto_spell | bool | True | 토시 자동 교정 |
# | replace_mode | bool | True | 찾아 바꾸기 모드 |
# | ignore_find_string | bool | False | 찾을 문자열 무시 |
# | ignore_replace_string | bool | False | 바꿀 문자열 무시 |
# | find_style | str |  | 찾을 스타일 |
# | replace_style | str |  | 바꿀 스타일 |
# | find_jaso | bool | False | 자소로 찾기 |
# | find_reg_exp | bool | False | 정규표현식으로 찾기 |
# | find_type | bool | True | 다시 찾기를 할 때 마지막으로 실한 찾기를 할 경우 True, 찾아가기를 할경우 False |

# %%
app.replace_all("t", "txt", new_fontname="가는안상수체", new_fontsize=21, new_fonttype=1)
# Out:
# False

# %%
app.replace_all(
    "",
    "",
    old_fontname="바탕체",
    new_fontname="바탕체",
    ignore_find_string=True,
    ignore_replace_string=True,
    new_fontsize=11,
    new_fonttype=1,
)
# Out:
# False

# %%
#| echo: false
#| output: asis
show_doc(App.insert_file)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L890){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.insert_file
#
# >      App.insert_file (app:__main__.App, fpath, keep_charshape=False,
# >                       keep_parashape=False, keep_section=False,
# >                       keep_style=False)
#
# 파일 끼워 넣기

# %%
#| echo: false
#| output: asis
show_doc(App.set_cell_border)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L914){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.set_cell_border
#
# >      App.set_cell_border (app:__main__.App, top=None, right=None, left=None,
# >                           bottom=None, horizontal=None, vertical=None,
# >                           top_width=None, right_width=None, left_width=None,
# >                           bottom_width=None, horizontal_width=None,
# >                           vertical_width=None, top_color=None,
# >                           bottom_color=None, left_color=None,
# >                           right_color=None, horizontal_color=None,
# >                           vertical_color=None)

# %%
#| echo: false
#| output: asis
show_doc(App.set_cell_color)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L990){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.set_cell_color
#
# >      App.set_cell_color (app:__main__.App, bg_color=None,
# >                          hatch_color='#000000', hatch_style=6, alpha=None)

# %%
app = App()

# %%
app.set_cell_border(bottom=3)
# Out:
# False

# %%
app.set_cell_color(bg_color=(123, 123, 123), hatch_style=6)
# Out:
# False
