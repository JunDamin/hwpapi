# %% [raw]
# ---
# description: Core Classes for hwpapi
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(App)
# Out:
# C:\Users\freed\.pyenv\pyenv-win\versions\3.10.1\lib\site-packages\fastcore\docscrape.py:225: UserWarning: potentially wrong underline length...
# 메소드
# ---------- in
# `App` 클래스는 한컴오피스의 한/글 프로그램과 상호작용하기 위한 인터페이스를 제공합니다.
# ...
#   else: warn(msg)
# C:\Users\freed\.pyenv\pyenv-win\versions\3.10.1\lib\site-packages\fastcore\docscrape.py:225: UserWarning: Unknown section 메소드
#   else: warn(msg)
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L34){target="_blank" style="float:right; font-size:smaller"}
#
# ### App
#
# >      App (api=None, is_visible=True)
#
# `App` 클래스는 한컴오피스의 한/글 프로그램과 상호작용하기 위한 인터페이스를 제공합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.reload)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L74){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.reload
#
# >      App.reload (app:__main__.App)

# %%
#| echo: false
#| output: asis
show_doc(App.set_visible)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L82){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.set_visible
#
# >      App.set_visible (app:__main__.App, is_visible=True, window_i=0)
#
# `set_visible()` 함수는 한/글 프로그램의 창을 화면에 보이거나 숨기기 위해 호출됩니다.
# `is_visible` 인자가 `True`일 경우 창이 화면에 보이고, `False`일 경우 숨깁니다.
# `window_i` 인자는 창의 인덱스를 지정합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.get_filepath)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L91){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.get_filepath
#
# >      App.get_filepath (app:__main__.App)
#
# `get_filepath()` 함수는 현재 열려있는 한/글 문서의 경로를 반환합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.create_action)
# Out:
# C:\Users\freed\.pyenv\pyenv-win\versions\3.10.1\lib\site-packages\fastcore\docscrape.py:225: UserWarning: potentially wrong underline length...
# 매개변수
# ---------- in
# `create_action` 함수는 `_Action` 클래스의 인스턴스를 생성하고 반환합니다.
# ...
#   else: warn(msg)
# C:\Users\freed\.pyenv\pyenv-win\versions\3.10.1\lib\site-packages\fastcore\docscrape.py:225: UserWarning: potentially wrong underline length...
# 반환
# ------ in
# `create_action` 함수는 `_Action` 클래스의 인스턴스를 생성하고 반환합니다.
# ...
#   else: warn(msg)
# C:\Users\freed\.pyenv\pyenv-win\versions\3.10.1\lib\site-packages\fastcore\docscrape.py:225: UserWarning: Unknown section 매개변수
#   else: warn(msg)
# C:\Users\freed\.pyenv\pyenv-win\versions\3.10.1\lib\site-packages\fastcore\docscrape.py:225: UserWarning: Unknown section 반환
#   else: warn(msg)
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L98){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.create_action
#
# >      App.create_action (app:__main__.App, action_key:str)
#
# `create_action` 함수는 `_Action` 클래스의 인스턴스를 생성하고 반환합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.create_parameterset)
# Out:
# C:\Users\freed\.pyenv\pyenv-win\versions\3.10.1\lib\site-packages\fastcore\docscrape.py:225: UserWarning: potentially wrong underline length...
# 매개변수
# ---------- in
# `create_parameterset` 함수는 특정 액션에 대한 파라미터셋을 생성하고 반환합니다.
# ...
#   else: warn(msg)
# C:\Users\freed\.pyenv\pyenv-win\versions\3.10.1\lib\site-packages\fastcore\docscrape.py:225: UserWarning: potentially wrong underline length...
# 반환
# ------ in
# `create_parameterset` 함수는 특정 액션에 대한 파라미터셋을 생성하고 반환합니다.
# ...
#   else: warn(msg)
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L119){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.create_parameterset
#
# >      App.create_parameterset (app:__main__.App, action_key:str)
#
# `create_parameterset` 함수는 특정 액션에 대한 파라미터셋을 생성하고 반환합니다.
#
# `_action_info` 딕셔너리를 사용하여 주어진 액션 키에 대한 파라미터셋 정보를 조회합니다.
# 파라미터셋 정보가 있으면 해당 파라미터셋 객체를 생성하고 반환합니다.

# %%
app = App()

# %%
#| echo: false
#| output: asis
show_doc(App.open)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L147){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.open
#
# >      App.open (app:__main__.App, path:str)
#
# `open()` 함수는 파일 경로를 인자로 받아 해당 파일을 한/글 프로그램에서 엽니다.
# `get_absolute_path()` 함수를 호출하여 절대 경로로 변환한 후, `api.Open()` 함수를 호출하여 파일을 엽니다.
# 열린 파일의 경로를 반환합니다.

# %%
app.open("test/공문양식.hwp")
# Out:
# 'c:/Users/freed/Documents/python_projects/HwpApi/nbs/02_api/test/공문양식.hwp'

# %%
#| echo: false
#| output: asis
show_doc(App.get_hwnd)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L157){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.get_hwnd
#
# >      App.get_hwnd (app:__main__.App)

# %%
app.get_hwnd()
# Out:
# 657134

# %%
#| echo: false
#| output: asis
show_doc(App.save)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L162){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.save
#
# >      App.save (app:__main__.App, path=None)

# %%
app.save("test.pdf")
# Out:
# 'c:/Users/freed/Documents/python_projects/HwpApi/nbs/02_api/test.pdf'

# %%
#| echo: false
#| output: asis
show_doc(App.save_block)
# Out:
# C:\Users\freed\.pyenv\pyenv-win\versions\3.10.1\lib\site-packages\fastcore\docscrape.py:225: UserWarning: potentially wrong underline length...
# 매개변수
# ---------- in
# `save_block` 함수는 블록을 저장하고 주소를 반환합니다.
# ...
#   else: warn(msg)
# C:\Users\freed\.pyenv\pyenv-win\versions\3.10.1\lib\site-packages\fastcore\docscrape.py:225: UserWarning: potentially wrong underline length...
# 반환
# ------ in
# `save_block` 함수는 블록을 저장하고 주소를 반환합니다.
# ...
#   else: warn(msg)
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L183){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.save_block
#
# >      App.save_block (app:__main__.App, path:pathlib.Path)
#
# `save_block` 함수는 블록을 저장하고 주소를 반환합니다.

# %%
app.save_block("test2.hwp")

# %%
#| echo: false
#| output: asis
show_doc(App.close)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L219){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.close
#
# >      App.close (app:__main__.App)
#
# `close()` 함수는 현재 열려있는 문서를 닫습니다.

# %%
app.close()

# %%
#| echo: false
#| output: asis
show_doc(App.quit)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L225){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.quit
#
# >      App.quit (app:__main__.App)
#
# `quit()` 함수는 한/글 프로그램을 종료합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.get_charshape)
# Out:
# C:\Users\freed\.pyenv\pyenv-win\versions\3.10.1\lib\site-packages\fastcore\docscrape.py:225: UserWarning: potentially wrong underline length...
# 매개변수
# ---------- in
# `get_charshape` 메소드는 현재 애플리케이션에서 문자 모양을 가져오는 함수입니다.
# ...
#   else: warn(msg)
# C:\Users\freed\.pyenv\pyenv-win\versions\3.10.1\lib\site-packages\fastcore\docscrape.py:225: UserWarning: potentially wrong underline length...
# 반환
# ------ in
# `get_charshape` 메소드는 현재 애플리케이션에서 문자 모양을 가져오는 함수입니다.
# ...
#   else: warn(msg)
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L231){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.get_charshape
#
# >      App.get_charshape (app:__main__.App)
#
# `get_charshape` 메소드는 현재 애플리케이션에서 문자 모양을 가져오는 함수입니다.

# %%
app.get_charshape()
# Out:
# <CharShape: hangul_font=함초롬바탕, latin_font=함초롬바탕, text_color=0, fontsize=10.0, bold=0, italic=0, super_script=0, sub_script=0, offset=0, spacing=0, ratio=100, shade_color=#ffffff, shadow_color=#c0c0c0, shadow_offset_x=10, shadow_offset_y=10, strike_out_type=0, strike_out_color=0, underline_type=0, underline_shape=0, underline_color=0, out_line_type=0>

# %%
#| echo: false
#| output: asis
show_doc(App.set_charshape)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L251){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.set_charshape
#
# >      App.set_charshape (app:__main__.App,
# >                         charshape:hwpapi.dataclasses.CharShape=None, **kwargs)
#
# `set_charshape` 함수는 주어진 `CharShape`를 사용하여 애플리케이션의 현재 문단 모양을 설정합니다.
#
# 만약 `charshape`가 `None`인 경우, `CharShape`의 기본 인스턴스를 생성합니다.
#
# 이 함수는 추가로 `kwargs`를 인자로 받아, 이를 `parashape`의 속성에 할당합니다.
# 이렇게 수정된 `parashape`는 한/글 문서의 현재 문단 모양을 변경하는데 사용됩니다.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | app | App |  | `App` 객체입니다. 한/글 애플리케이션에 접근하는데 사용됩니다. |
# | charshape | CharShape | None | 한/글 글자 모양을 설정하는데 사용될 `CharShape` 객체입니다. 기본값은 `None`입니다. |
# | kwargs |  |  |  |
# | **Returns** | **bool** |  | **`set_charshape` 작업의 성공 여부를 나타내는 부울 값입니다.** |

# %%
charshape = CharShape()
charshape.font = "바탕체"
charshape.super_script=1
charshape.sub_script = 1
app.set_charshape(charshape)
# Out:
# True

# %%
app.get_charshape()
# Out:
# <CharShape: hangul_font=바탕체, latin_font=바탕체, text_color=0, fontsize=10.0, bold=0, italic=0, super_script=1, sub_script=1, offset=0, spacing=0, ratio=100, shade_color=#ffffff, shadow_color=#c0c0c0, shadow_offset_x=10, shadow_offset_y=10, strike_out_type=0, strike_out_color=0, underline_type=0, underline_shape=0, underline_color=0, out_line_type=0>

# %%
charshape = CharShape()
charshape.font = "바탕체"
charshape.super_script=0
app.set_charshape(charshape)
charshape = app.get_charshape()

charshape.super_script == 0
# Out:
# True

# %%
#| echo: false
#| output: asis
show_doc(App.get_parashape)
# Out:
# C:\Users\freed\.pyenv\pyenv-win\versions\3.10.1\lib\site-packages\fastcore\docscrape.py:225: UserWarning: potentially wrong underline length...
# 매개변수
# ---------- in
# `get_parashape` 메소드는 현재 애플리케이션에서 문단 모양을 가져오는 함수입니다.
# ...
#   else: warn(msg)
# C:\Users\freed\.pyenv\pyenv-win\versions\3.10.1\lib\site-packages\fastcore\docscrape.py:225: UserWarning: potentially wrong underline length...
# 반환
# ------ in
# `get_parashape` 메소드는 현재 애플리케이션에서 문단 모양을 가져오는 함수입니다.
# ...
#   else: warn(msg)
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L285){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.get_parashape
#
# >      App.get_parashape (app:__main__.App)
#
# `get_parashape` 메소드는 현재 애플리케이션에서 문단 모양을 가져오는 함수입니다.

# %%
app.get_parashape()
# Out:
# <ParaShape: left_margin=0, right_margin=0, indentation=0, prev_spacing=0, next_spacing=0, line_spacing_type=Word, line_spacing=160, align_type=Both, break_latin_word=Word, break_non_latin_word=1, snap_to_grid=1, condense=0, widow_orphan=0, keep_with_next=0, page_break_before=0, text_alignment=Font, font_line_height=0, heading_type=None, level=0, border_connect=0, border_text=0, border_offset_left=0, border_offset_right=0, border_offset_top=0, border_offset_bottom=0, tail_type=0, line_wrap=0>

# %%
#| echo: false
#| output: asis
show_doc(App.set_parashape)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L306){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.set_parashape
#
# >      App.set_parashape (app:__main__.App,
# >                         parashape:hwpapi.dataclasses.ParaShape=None, **kwargs)
#
# `set_parashape` 함수는 주어진 `ParaShape`를 사용하여 애플리케이션의 현재 문단 모양을 설정합니다.
#
# 만약 `parashape`가 `None`인 경우, `ParaShape`의 기본 인스턴스를 생성합니다.
#
# 이 함수는 추가로 `kwargs`를 인자로 받아, 이를 `parashape`의 속성에 할당합니다.
# 이렇게 수정된 `parashape`는 한/글 문서의 현재 문단 모양을 변경하는데 사용됩니다.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | app | App |  | `App` 객체입니다. 한/글 애플리케이션에 접근하는데 사용됩니다. |
# | parashape | ParaShape | None | 한/글 문단 모양을 설정하는데 사용될 `ParaShape` 객체입니다. 기본값은 `None`입니다. |
# | kwargs |  |  |  |
# | **Returns** | **bool** |  | **`set_parashape` 작업의 성공 여부를 나타내는 부울 값입니다.** |

# %%
app.set_parashape(line_spacing=100)
# Out:
# True

# %%
#| echo: false
#| output: asis
show_doc(App.insert_text)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L340){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.insert_text
#
# >      App.insert_text (app:__main__.App, text:str,
# >                       charshape:hwpapi.dataclasses.CharShape=None)
#
# `text를 입력합니다.

# %%
app.insert_text("안녕하세요", charshape)

# %%
app.set_parashape(ParaShape(right_margin=20, align_type="Left"))
# Out:
# True

# %%
parashape = app.actions.ParagraphShape()

# %%
parashape.pset.RightMargin
# Out:
# 5660

# %%
#| echo: false
#| output: asis
show_doc(App.scan)
# Out:
# ---
#
# ### scan
#
# >      scan (app:__main__.App, option='All', selection=False,
# >            scan_spos='Document', scan_epos='Document', spara=None, spos=None,
# >            epara=None, epos=None, scan_direction='Forward')

# %%
#| echo: false
#| output: asis
show_doc(move_to_line)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L436){target="_blank" style="float:right; font-size:smaller"}
#
# ### move_to_line
#
# >      move_to_line (app:__main__.App, text)
#
# 인자로 전달한 텍스트가 있는 줄의 시작지점으로 이동합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.move)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L488){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.move
#
# >      App.move (app:__main__.App, key='ScanPos', para=None, pos=None)
#
# 키워드를 바탕으로 캐럿 위치를 이동시킵니다.

# %%
get_value(move_ids, "ScanPos")
# Out:
# 201

# %%
#| echo: false
#| output: asis
show_doc(App.setup_page)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L496){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.setup_page
#
# >      App.setup_page (app:__main__.App, top=20, bottom=10, right=20, left=20,
# >                      header=15, footer=5, gutter=0)
#
# 페이지를 설정합니다.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | app | App |  | app |
# | top | int | 20 | 윗 여백 |
# | bottom | int | 10 | 아래 여백 |
# | right | int | 20 | 오른쪽 여백 |
# | left | int | 20 | 왼쪽 여백 |
# | header | int | 15 | 머릿말 |
# | footer | int | 5 | 꼬릿말 |
# | gutter | int | 0 |  |

# %%
#| echo: false
#| output: asis
show_doc(App.insert_picture)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L538){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.insert_picture
#
# >      App.insert_picture (app:__main__.App, fpath, width=None, height=None,
# >                          size_option='realSize', reverse=False,
# >                          watermark=False, effect='RealPicture')
#
# 사이즈를 지정하여 사진 삽입
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | app | App |  | app |
# | fpath |  |  | 그림 위치 |
# | width | NoneType | None | 넓이 |
# | height | NoneType | None | 높이 |
# | size_option | str | realSize | 사이즈 옵션 |
# | reverse | bool | False | 이미지 반전 여부 |
# | watermark | bool | False | 워커마크 여부 |
# | effect | str | RealPicture | 화면 효과 |

# %%
#| echo: false
#| output: asis
show_doc(App.select_text)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L566){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.select_text
#
# >      App.select_text (app:__main__.App, option:str='Line')
#
# 한줄을 선택합니다.

# %%
app.select_text()
# Out:
# (True, True)

# %%
app.set_charshape(CharShape(font="바탕", fontsize=20))
# Out:
# True

# %%
#| echo: false
#| output: asis
show_doc(App.get_selected_text)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L581){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.get_selected_text
#
# >      App.get_selected_text (app:__main__.App)
#
# 선택된 영역의 텍스트를 불러온다.

# %%
app.get_selected_text()
# Out:
# '안녕하세요\n'

# %%
#| echo: false
#| output: asis
show_doc(App.get_text)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L591){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.get_text
#
# >      App.get_text (app:__main__.App, spos='Line', epos='Line')
#
# 텍스트를 가져옵니다. 기본은 현재 문장입니다.
# "Current":  # "캐럿 위치부터. (현재 위치까지)",
# "Specified": 0x0010,  # "특정 위치부터. (특정 위치까지)",
# "Line": 0x0020,  # "줄의 시작부터. (줄 끝까지)",
# "Paragraph": 0x0030,  # "문단의 시작부터. (문단 끝까지)"
# "Section": 0x0040,  # "구역의 시작부터. (구역의 끝까지)"
# "List": 0x0050,  # "리스트의 시작부터. (리스트 끝까지)"
# "Control": 0x0060,  # "컨트롤의 시작부터. (컨트롤 끝까지)"
# "Document": 0x0070,  # "문서의 시작부터. (문서 끝까지)"

# %%
app.get_text()
# Out:
# '안녕하세요\r\n'

# %%
#| echo: false
#| output: asis
show_doc(App.find_text)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L604){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.find_text
#
# >      App.find_text (app:__main__.App, text='',
# >                     charshape:hwpapi.dataclasses.CharShape=None,
# >                     ignore_message=True, direction='Forward',
# >                     match_case=False, all_word_forms=False,
# >                     several_words=False, use_wild_cards=False,
# >                     whole_word_only=False, replace_mode=False,
# >                     ignore_find_string=False, ignore_replace_string=False,
# >                     find_style='', replace_style='', find_jaso=False,
# >                     find_reg_exp=False, find_type=False)
#
# text를 찾습니다.
# 찾지못하면 False를 반환합니다.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | app | App |  |  |
# | text | str |  |  |
# | charshape | CharShape | None |  |
# | ignore_message | bool | True | 메시지 무시 여부 |
# | direction | str | Forward | 찾을 방향 |
# | match_case | bool | False | 대소문자 구분 |
# | all_word_forms | bool | False | 문자열 결합 |
# | several_words | bool | False | 여러 단어 찾기 |
# | use_wild_cards | bool | False | 아무개 문자 |
# | whole_word_only | bool | False | 온전한 낱말 |
# | replace_mode | bool | False | 찾아 바꾸기 모드 |
# | ignore_find_string | bool | False | 찾을 문자열 무시 |
# | ignore_replace_string | bool | False | 바꿀 문자열 무시 |
# | find_style | str |  | 찾을 스타일 |
# | replace_style | str |  |  |
# | find_jaso | bool | False | 자소로 찾기 |
# | find_reg_exp | bool | False | 정규표현식으로 찾기 |
# | find_type | bool | False | 다시 찾기를 할 때 마지막으로 실한 찾기를 할 경우 True, 찾아가기를 할경우 False |

# %%
app.find_text("안녕하세요")
# Out:
# False

# %%
#| echo: false
#| output: asis
show_doc(App.replace_all)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L658){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.replace_all
#
# >      App.replace_all (app:__main__.App, old_text='', new_text='',
# >                       old_charshape:hwpapi.dataclasses.CharShape=None,
# >                       new_charshape:hwpapi.dataclasses.CharShape=None,
# >                       ignore_message=True, direction='All', match_case=False,
# >                       all_word_forms=False, several_words=False,
# >                       use_wild_cards=False, whole_word_only=False,
# >                       auto_spell=True, replace_mode=True,
# >                       ignore_find_string=False, ignore_replace_string=False,
# >                       find_style='', replace_style='', find_jaso=False,
# >                       find_reg_exp=False, find_type=True)
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | app | App |  |  |
# | old_text | str |  |  |
# | new_text | str |  |  |
# | old_charshape | CharShape | None |  |
# | new_charshape | CharShape | None |  |
# | ignore_message | bool | True | 메시지 무시 여부 |
# | direction | str | All | 찾을 방향 |
# | match_case | bool | False | 대소문자 구분 |
# | all_word_forms | bool | False | 문자열 결합 |
# | several_words | bool | False | 여러 단어 찾기 |
# | use_wild_cards | bool | False | 아무개 문자 |
# | whole_word_only | bool | False | 온전한 낱말 |
# | auto_spell | bool | True | 토시 자동 교정 |
# | replace_mode | bool | True | 찾아 바꾸기 모드 |
# | ignore_find_string | bool | False | 찾을 문자열 무시 |
# | ignore_replace_string | bool | False | 바꿀 문자열 무시 |
# | find_style | str |  | 찾을 스타일 |
# | replace_style | str |  | 바꿀 스타일 |
# | find_jaso | bool | False | 자소로 찾기 |
# | find_reg_exp | bool | False | 정규표현식으로 찾기 |
# | find_type | bool | True | 다시 찾기를 할 때 마지막으로 실한 찾기를 할 경우 True, 찾아가기를 할경우 False |

# %%
app.insert_text("t")

# %%
app.replace_all("t", "txt", new_charshape=CharShape(hangul_font="가는안상수체", fontsize=21))
# Out:
# True

# %%
#| echo: false
#| output: asis
show_doc(App.insert_file)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L715){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.insert_file
#
# >      App.insert_file (app:__main__.App, fpath, keep_charshape=False,
# >                       keep_parashape=False, keep_section=False,
# >                       keep_style=False)
#
# 파일 끼워 넣기

# %%
#| echo: false
#| output: asis
show_doc(App.set_cell_border)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L739){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.set_cell_border
#
# >      App.set_cell_border (app:__main__.App, top=None, right=None, left=None,
# >                           bottom=None, horizontal=None, vertical=None,
# >                           top_width=None, right_width=None, left_width=None,
# >                           bottom_width=None, horizontal_width=None,
# >                           vertical_width=None, top_color=None,
# >                           bottom_color=None, left_color=None,
# >                           right_color=None, horizontal_color=None,
# >                           vertical_color=None)

# %%
#| echo: false
#| output: asis
show_doc(App.set_cell_color)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/core.py#L815){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.set_cell_color
#
# >      App.set_cell_color (app:__main__.App, bg_color=None,
# >                          hatch_color='#000000', hatch_style=6, alpha=None)

# %%
app = App()

# %%
app.set_charshape(CharShape(hangul_font="문화바탕", font_type=2))
# Out:
# True

# %%
action = app.actions.CharShape()

# %%
app.get_charshape()
# Out:
# <CharShape: hangul_font=문화바탕, latin_font=함초롬바탕, text_color=0, fontsize=10.0, bold=0, italic=0, super_script=0, sub_script=0, offset=0, spacing=0, ratio=100, shade_color=#ffffff, shadow_color=#c0c0c0, shadow_offset_x=10, shadow_offset_y=10, strike_out_type=0, strike_out_color=0, underline_type=0, underline_shape=0, underline_color=0, out_line_type=0>

# %%
app.api.HwpLineWidth("1.0mm")
# Out:
# 10

# %%
app.set_cell_border(bottom=3)
# Out:
# False

# %%
app.set_cell_color(bg_color=(123, 123, 123), hatch_style=6)
# Out:
# False
