# %% [markdown]
# ---
# description: action list
# output-file: functions.html
# title: functions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(get_font_name)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L19){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_font_name
#
# >      get_font_name (text)

# %%
#| echo: false
#| output: asis
show_doc(dispatch)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L24){target="_blank" style="float:right; font-size:smaller"}
#
# ### dispatch
#
# >      dispatch (app_name:str)
#
# 캐시가 충돌하는 문제를 해결하기 위해 실행합니다. 에러가 발생할 경우 기존 캐시를 삭제하고 다시 불러옵니다.

# %%
#| echo: false
#| output: asis
show_doc(get_absolute_path)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L49){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_absolute_path
#
# >      get_absolute_path (path)
#
# 파일 절대 경로를 반환합니다.

# %%
#| echo: false
#| output: asis
show_doc(get_dll_path)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L55){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_dll_path
#
# >      get_dll_path (package_name, dll_filename)
#
# 패키지에서 dll 경로를 확보합니다.

# %%
#| echo: false
#| output: asis
show_doc(add_dll_to_registry)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L66){target="_blank" style="float:right; font-size:smaller"}
#
# ### add_dll_to_registry
#
# >      add_dll_to_registry (dll_path, key_path)
#
# 레지스트리에 dll을 등록합니다.

# %%
#| echo: false
#| output: asis
show_doc(get_registry_value)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L86){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_registry_value
#
# >      get_registry_value (key_path, value_name)
#
# 레지스트리에 값이 있는지 확인해 봅니다.

# %%
#| echo: false
#| output: asis
show_doc(check_dll)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L96){target="_blank" style="float:right; font-size:smaller"}
#
# ### check_dll
#
# >      check_dll (dll_path=None)
#
# dll 모듈을 등록합니다.

# %%
#| echo: false
#| output: asis
show_doc(get_value)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L109){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_value
#
# >      get_value (dict_, key)
#
# 딕셔너리에서 키를 찾아 값을 반환합니다. 반환할 값이 없으면 키에러와 함께 가능한 키를 알려줍니다.

# %%
#| echo: false
#| output: asis
show_doc(get_key)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L121){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_key
#
# >      get_key (dict_, value)
#
# 딕셔너리에서 값를 찾아 키를 반환합니다. 반환할 값이 없으면 키에러와 함께 가능한 키를 알려줍니다.

# %%
#| echo: false
#| output: asis
show_doc(convert2int)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L133){target="_blank" style="float:right; font-size:smaller"}
#
# ### convert2int
#
# >      convert2int (_dict, value)

# %%
#| echo: false
#| output: asis
show_doc(set_pset)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L144){target="_blank" style="float:right; font-size:smaller"}
#
# ### set_pset
#
# >      set_pset (p, value_dict:dict)

# %%
#| echo: false
#| output: asis
show_doc(get_charshape_pset)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L154){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_charshape_pset
#
# >      get_charshape_pset (p)

# %%
#| echo: false
#| output: asis
show_doc(set_charshape_pset)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L158){target="_blank" style="float:right; font-size:smaller"}
#
# ### set_charshape_pset
#
# >      set_charshape_pset (charshape_pset, value_dict:dict)
#
# CharShape값을 입력하기 위한 함수입니다.
# char_fields에 정의된 키 값을 기반으로 파라미터를 세팅합니다.

# %%
#| echo: false
#| output: asis
show_doc(get_parashape_pset)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L175){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_parashape_pset
#
# >      get_parashape_pset (p)

# %%
#| echo: false
#| output: asis
show_doc(set_parashape_pset)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L180){target="_blank" style="float:right; font-size:smaller"}
#
# ### set_parashape_pset
#
# >      set_parashape_pset (parashape_pset, value_dict:dict)

# %%
#| echo: false
#| output: asis
show_doc(get_rgb_tuple)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L208){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_rgb_tuple
#
# >      get_rgb_tuple (color)

# %%
#| echo: false
#| output: asis
show_doc(hex_to_rgb)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L194){target="_blank" style="float:right; font-size:smaller"}
#
# ### hex_to_rgb
#
# >      hex_to_rgb (hex_string)

# %%
#| echo: false
#| output: asis
show_doc(convert_to_hwp_color)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L252){target="_blank" style="float:right; font-size:smaller"}
#
# ### convert_to_hwp_color
#
# >      convert_to_hwp_color (color)

# %%
#| echo: false
#| output: asis
show_doc(convert_hwp_color_to_hex)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L282){target="_blank" style="float:right; font-size:smaller"}
#
# ### convert_hwp_color_to_hex
#
# >      convert_hwp_color_to_hex (color:int)

# %%
print(convert_to_hwp_color("00FFFF"))  # Outputs: 65535
print(convert_to_hwp_color((0, 255, 255)))  # Outputs: 65535
# Out:
# 16776960
# 16776960

# %%
#| echo: false
#| output: asis
show_doc(mili2unit)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L290){target="_blank" style="float:right; font-size:smaller"}
#
# ### mili2unit
#
# >      mili2unit (value)
#
# 1 밀리는 283 hwpunit 입니다.

# %%
#| echo: false
#| output: asis
show_doc(unit2mili)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L297){target="_blank" style="float:right; font-size:smaller"}
#
# ### unit2mili
#
# >      unit2mili (value)

# %%
#| echo: false
#| output: asis
show_doc(point2unit)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L301){target="_blank" style="float:right; font-size:smaller"}
#
# ### point2unit
#
# >      point2unit (value)
#
# 1point는 100 hwpunit입니다.

# %%
#| echo: false
#| output: asis
show_doc(unit2point)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L308){target="_blank" style="float:right; font-size:smaller"}
#
# ### unit2point
#
# >      unit2point (value)

# %%
#| echo: false
#| output: asis
show_doc(block_input)
# Out:
# ---
#
# ### block_input
#
# >      block_input (func)
#
# 함수가 실행될 동안 다른 입력을 할 수 없게 하는 기능을 가진 데코레이터입니다.
