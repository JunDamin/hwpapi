# %% [markdown]
# ---
# description: action list
# output-file: fnctions.html
# title: functions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#| echo: false
#| output: asis
show_doc(dispatch)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### dispatch
#
# >      dispatch (app_name:str)
#
# 캐시가 충돌하는 문제를 해결하기 위해 실행합니다. 에러가 발생할 경우 기존 캐시를 삭제하고 다시 불러옵니다.

# %%
#| echo: false
#| output: asis
show_doc(get_absolute_path)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L37){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_absolute_path
#
# >      get_absolute_path (path)
#
# 파일 절대 경로를 반환합니다.

# %%
#| echo: false
#| output: asis
show_doc(get_dll_path)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L43){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_dll_path
#
# >      get_dll_path (package_name, dll_filename)
#
# 패키지에서 dll 경로를 확보합니다.

# %%
#| echo: false
#| output: asis
show_doc(add_dll_to_registry)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L53){target="_blank" style="float:right; font-size:smaller"}
#
# ### add_dll_to_registry
#
# >      add_dll_to_registry (dll_path, key_path)
#
# 레지스트리에 dll을 등록합니다.

# %%
#| echo: false
#| output: asis
show_doc(get_registry_value)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L70){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_registry_value
#
# >      get_registry_value (key_path, value_name)
#
# 레지스트리에 값이 있는지 확인해 봅니다.

# %%
#| echo: false
#| output: asis
show_doc(check_dll)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L80){target="_blank" style="float:right; font-size:smaller"}
#
# ### check_dll
#
# >      check_dll ()
#
# dll 모듈을 등록합니다.

# %%
#| echo: false
#| output: asis
show_doc(get_value)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L94){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_value
#
# >      get_value (dict_, key)
#
# 딕셔너리에서 키를 찾아 값을 반환합니다. 반환할 값이 없으면 키에러와 함께 가능한 키를 알려줍니다.

# %%
#| echo: false
#| output: asis
show_doc(set_charshape_pset)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L102){target="_blank" style="float:right; font-size:smaller"}
#
# ### set_charshape_pset
#
# >      set_charshape_pset (charshape, face_name:str=None, font_type:int=None,
# >                          size:int=None, ratio:int=None, spacing:int=None,
# >                          offset:int=None, bold:bool=None, italic:bool=None,
# >                          small_caps:bool=None, emboss:bool=None,
# >                          super_script:bool=None, sub_script:bool=None,
# >                          underline_type:int=None, outline_type:int=None,
# >                          text_color=None, shade_color=None,
# >                          underline_shape:int=None, underline_color=None,
# >                          shadow_offset_x:int=None, shadow_offset_y:int=None,
# >                          shadow_color=None, strike_out_type=None,
# >                          diac_sym_mark=None, use_font_space=None,
# ...

# %%
#| echo: false
#| output: asis
show_doc(hex_to_rgb)
# Out:
# ---
#
# [source](https://github.com/JunDamin/hwpapi/blob/main/hwpapi/functions.py#L178){target="_blank" style="float:right; font-size:smaller"}
#
# ### hex_to_rgb
#
# >      hex_to_rgb (hex_string)
