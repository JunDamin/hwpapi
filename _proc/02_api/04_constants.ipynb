# %% [markdown]
# ---
# description: constants
# output-file: constants.html
# title: constants
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(ScanDirection)
# Out:
# ---
#
# ### ScanDirection
#
# >      ScanDirection (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
#| echo: false
#| output: asis
show_doc(ScanEndPosition)
# Out:
# ---
#
# ### ScanEndPosition
#
# >      ScanEndPosition (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
#| echo: false
#| output: asis
show_doc(ScanStartPosition)
# Out:
# ---
#
# ### ScanStartPosition
#
# >      ScanStartPosition (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
#| echo: false
#| output: asis
show_doc(MaskOption)
# Out:
# ---
#
# ### MaskOption
#
# >      MaskOption (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
#| echo: false
#| output: asis
show_doc(MoveId)
# Out:
# ---
#
# ### MoveId
#
# >      MoveId (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
#| echo: false
#| output: asis
show_doc(Effect)
# Out:
# ---
#
# ### Effect
#
# >      Effect (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
#| echo: false
#| output: asis
show_doc(SizeOption)
# Out:
# ---
#
# ### SizeOption
#
# >      SizeOption (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
#| echo: false
#| output: asis
show_doc(SelectionOption)
# Out:
# ---
#
# ### SelectionOption
#
# >      SelectionOption (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
#| echo: false
#| output: asis
show_doc(ScanEndPosition)
# Out:
# ---
#
# ### ScanEndPosition
#
# >      ScanEndPosition (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
#| echo: false
#| output: asis
show_doc(ScanStartPosition)
# Out:
# ---
#
# ### ScanStartPosition
#
# >      ScanStartPosition (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
#| echo: false
#| output: asis
show_doc(Direction)
# Out:
# ---
#
# ### Direction
#
# >      Direction (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
#| echo: false
#| output: asis
show_doc(Thickness)
# Out:
# ---
#
# ### Thickness
#
# >      Thickness (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*
