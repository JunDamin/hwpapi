# %% [markdown]
# ---
# description: action list
# output-file: variables.html
# title: actions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
