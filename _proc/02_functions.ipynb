# %% [markdown]
# ---
# description: action list
# output-file: fnctions.html
# title: functions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#| echo: false
#| output: asis
show_doc(dispatch)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### dispatch
#
# >      dispatch (app_name:str)

# %%
#| echo: false
#| output: asis
show_doc(get_absolute_path)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/functions.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_absolute_path
#
# >      get_absolute_path (path)

# %%
#| echo: false
#| output: asis
show_doc(get_dll_path)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/functions.py#L17){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_dll_path
#
# >      get_dll_path (package_name, dll_filename)

# %%
#| echo: false
#| output: asis
show_doc(get_registry_value)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/functions.py#L45){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_registry_value
#
# >      get_registry_value (key_path, value_name)

# %%
#| echo: false
#| output: asis
show_doc(add_dll_to_registry)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/functions.py#L30){target="_blank" style="float:right; font-size:smaller"}
#
# ### add_dll_to_registry
#
# >      add_dll_to_registry (dll_path, key_path)

# %%
#| echo: false
#| output: asis
show_doc(check_dll)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/functions.py#L55){target="_blank" style="float:right; font-size:smaller"}
#
# ### check_dll
#
# >      check_dll ()

# %%
#| echo: false
#| output: asis
show_doc(get_value)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/functions.py#L68){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_value
#
# >      get_value (dict_, key)

# %%
#| echo: false
#| output: asis
show_doc(set_charshape)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/functions.py#L75){target="_blank" style="float:right; font-size:smaller"}
#
# ### set_charshape
#
# >      set_charshape (charshape, face_name:str=None, font_type:int=None,
# >                     size:int=None, ratio:int=None, spacing:int=None,
# >                     offset:int=None, bold:bool=None, italic:bool=None,
# >                     small_caps:bool=None, emboss:bool=None,
# >                     super_script:bool=None, sub_script:bool=None,
# >                     underline_type:int=None, outline_type:int=None,
# >                     text_color=None, shade_color=None,
# >                     underline_shape:int=None, underline_color=None,
# >                     shadow_offset_x:int=None, shadow_offset_y:int=None,
# >                     shadow_color=None, strike_out_type=None,
# >                     diac_sym_mark=None, use_font_space=None, use_kerning=None,
# >                     height:int=None)
#
# CharShape값을 입력하기 위한 함수입니다.
# `BorderFill`은 별도로 "BorderFill"타입을 사용하기 때문에 제외하였습니다.
