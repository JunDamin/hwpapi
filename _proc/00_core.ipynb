# %% [raw]
# ---
# description: Core Classes for HwpApi
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# nbdev 한글 문제 해결을 위해서는 encoding을 바꾸어야 합니다.
#
# 1. doclinks.py에서 49번째 줄 p.read_text()를 p.read_text(encoding='utf-8')으로 바꾸면 됩니다.(총 3가지가 있어서 찾아바꾸기가 좋은 것 같습니다.)
# 2. serve.py 파일에서도 25번째 줄에 p.read_text()를 p.read_text(encoding='utf-8)
# 3. setup에 있는 read 도 바꾸어야 합니다.

# %% [markdown]
# ### gencache error 해결
#
# 캐시가 충돌하는 문제를 해결하기 위해서 장치를 마련했습니다.
# 오류가 나는지 확인은 필요할 것으로 보입니다.

# %% [markdown]
# ### 필요한 패키지는 아래와 같습니다.

# %% [markdown]
# 액션을 좀더 쓰기 편하게 하기 위해서 구성하였습니다.

# %% [markdown]
# App은 기존 hwpali를 wrapping 하여 보다 사용하기 쉽게 만드는 것을 목적으로 하고 있는 클래스 입니다.
# 한글 컨트롤과 동등한 기능입니다.
# 기본 메소드를 보다 쓰기 쉽게 만들고자 합니다.
# 앞으로 추가할 기능은 화면 크기 조정 등이 있습니다.
# api 메소드를 통해 win32com의 방식으로 모두 사용할 수 있어 다양하게 사용할 수 있습니다.

# %% [markdown]
# 기본적으로는 [`App`](https://JunDamin.github.io/HwpApi/core.html#app) 클래스와 [`_Action`](https://JunDamin.github.io/HwpApi/core.html#_action)클래스가 있습니다.
# [`_Action`](https://JunDamin.github.io/HwpApi/core.html#_action) 클래스는 [`App`](https://JunDamin.github.io/HwpApi/core.html#app)로만 생성되어야 하기 때문에 언더바로 시작합니다.

# %%
#| echo: false
#| output: asis
show_doc(App)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L35){target="_blank" style="float:right; font-size:smaller"}
#
# ### App
#
# >      App (api=None)
#
# App 클래스는 한컴오피스의 한/글 프로그램과 상호작용하기 위한 인터페이스를 제공합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.set_visible)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L55){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.set_visible
#
# >      App.set_visible (app:__main__.App, is_visible=True, window_i=0)
#
# `set_visible()` 함수는 한/글 프로그램의 창을 화면에 보이거나 숨기기 위해 호출됩니다.
# `is_visible` 인자가 `True`일 경우 창이 화면에 보이고, `False`일 경우 숨깁니다.
# `window_i` 인자는 창의 인덱스를 지정합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.get_filepath)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L64){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.get_filepath
#
# >      App.get_filepath (app:__main__.App)
#
# `get_filepath()` 함수는 현재 열려있는 한/글 문서의 경로를 반환합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.open)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L71){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.open
#
# >      App.open (app:__main__.App, path:str)
#
# `open()` 함수는 파일 경로를 인자로 받아 해당 파일을 한/글 프로그램에서 엽니다.
# `get_absolute_path()` 함수를 호출하여 절대 경로로 변환한 후, `api.Open()` 함수를 호출하여 파일을 엽니다.
# 열린 파일의 경로를 반환합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.save)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L81){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.save
#
# >      App.save (app:__main__.App, path=None)
#
# `save()` 함수는 현재 열려있는 문서를 저장하거나 다른 이름으로 저장합니다.
# `path` 인자가 주어지지 않은 경우 현재 문서를 덮어쓰기로 저장하고, 저장된 파일의 경로를 반환합니다.
# `path` 인자가 주어진 경우, `Path` 모듈을 이용하여 파일 확장자를 추출한 후, 해당 확장자에 맞게 문서를 저장합니다.
# 저장된 파일의 경로를 반환합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.close)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L99){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.close
#
# >      App.close (app:__main__.App)
#
# `close()` 함수는 현재 열려있는 문서를 닫습니다.

# %%
#| echo: false
#| output: asis
show_doc(App.quit)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L105){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.quit
#
# >      App.quit (app:__main__.App)
#
# `quit()` 함수는 한/글 프로그램을 종료합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.create_action)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L111){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.create_action
#
# >      App.create_action (app:__main__.App, action_key:str)
#
# `create_action()` 함수는 `_Action` 클래스의 객체를 생성하여 반환합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.create_parameterset)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L117){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.create_parameterset
#
# >      App.create_parameterset (app:__main__.App, action_key:str)
#
# `create_parameterset()` 함수는 특정 액션의 파라미터셋을 반환합니다.
# `_action_info` 딕셔너리에서 액션에 대한 정보를 찾아서 파라미터셋의 키 값을 가져옵니다. 파라미터셋 객체를 반환합니다.

# %% [markdown]
# [`_Action`](https://JunDamin.github.io/HwpApi/core.html#_action)은 한글 문서 작업을 할 때 사용자의 각종 입력이라고 보시면 되며 연속된 액션을 통해 한글 문서 자동화가 진행되게 됩니다.

# %% [markdown]
# 한글 문서 사용은 다음과 같이 할 수 있습니다.
# 먼저 App 객체를 생성합니다.

# %%
app = App()

# %%
dir(app.api)
# Out:
# ['Application',
#  'ArcType',
#  'AutoNumType',
#  'BorderShape',
#  'BreakWordLatin',
#  'BrushType',
#  'CLSID',
#  'Canonical',
#  'CellApply',
#  'CellShape',
#  'CharShadowType',
#  'CharShape',
#  'CheckXObject',
#  'Clear',
#  'ColDefType',
#  'ColLayoutType',
#  'ConvertPUAHangulToUnicode',
#  'CreateAction',
#  'CreateField',
#  'CreateID',
#  'CreateMode',
#  'CreatePageImage',
#  'CreateSet',
#  'CrookedSlash',
#  'CurFieldState',
#  'CurMetatagState',
#  'CurSelectedCtrl',
#  'DSMark',
#  'DbfCodeType',
#  'DeleteCtrl',
#  'Delimiter',
#  'DrawAspect',
#  'DrawFillImage',
#  'DrawShadowType',
#  'EditMode',
#  'Encrypt',
#  'EndSize',
#  'EndStyle',
#  'EngineProperties',
#  'ExportStyle',
#  'FieldExist',
#  'FileTranslate',
#  'FillAreaType',
#  'FindCtrl',
#  'FindDir',
#  'FindPrivateInfo',
#  'FontType',
#  'GetBinDataPath',
#  'GetCurFieldName',
#  'GetCurMetatagName',
#  'GetFieldList',
#  'GetFieldText',
#  'GetFileInfo',
#  'GetFontList',
#  'GetHeadingString',
#  'GetMessageBoxMode',
#  'GetMetatagList',
#  'GetMetatagNameText',
#  'GetMousePos',
#  'GetPageText',
#  'GetPos',
#  'GetPosBySet',
#  'GetScriptSource',
#  'GetSelectedPos',
#  'GetSelectedPosBySet',
#  'GetText',
#  'GetTextFile',
#  'GetTranslateLangList',
#  'GetUserInfo',
#  'Gradation',
#  'GridMethod',
#  'GridViewLine',
#  'GutterMethod',
#  'HAction',
#  'HAlign',
#  'HParameterSet',
#  'Handler',
#  'Hash',
#  'HatchStyle',
#  'HeadCtrl',
#  'HeadType',
#  'HeightRel',
#  'Hiding',
#  'HorzRel',
#  'HwpLineType',
#  'HwpLineWidth',
#  'HwpOutlineStyle',
#  'HwpOutlineType',
#  'HwpUnderlineShape',
#  'HwpUnderlineType',
#  'HwpZoomType',
#  'ImageFormat',
#  'ImportStyle',
#  'InitHParameterSet',
#  'InitScan',
#  'Insert',
#  'InsertBackgroundPicture',
#  'InsertCtrl',
#  'InsertPicture',
#  'IsActionEnable',
#  'IsCommandLock',
#  'IsEmpty',
#  'IsModified',
#  'IsPrivateInfoProtected',
#  'IsTrackChange',
#  'IsTrackChangePassword',
#  'KeyIndicator',
#  'LastCtrl',
#  'LineSpacingMethod',
#  'LineWrapType',
#  'LockCommand',
#  'LunarToSolar',
#  'LunarToSolarBySet',
#  'MacroState',
#  'MailType',
#  'MetatagExist',
#  'MiliToHwpUnit',
#  'ModifyFieldProperties',
#  'ModifyMetatagProperties',
#  'MovePos',
#  'MoveToField',
#  'MoveToMetatag',
#  'NumberFormat',
#  'Numbering',
#  'Open',
#  'PageCount',
#  'PageNumPosition',
#  'PageType',
#  'ParaHeadAlign',
#  'ParaShape',
#  'ParentCtrl',
#  'Path',
#  'PicEffect',
#  'PlacementType',
#  'PointToHwpUnit',
#  'PresentEffect',
#  'PrintDevice',
#  'PrintPaper',
#  'PrintRange',
#  'PrintType',
#  'ProtectPrivateInfo',
#  'PutFieldText',
#  'PutMetatagNameText',
#  'Quit',
#  'RGBColor',
#  'RegisterModule',
#  'RegisterPrivateInfoPattern',
#  'ReleaseAction',
#  'ReleaseScan',
#  'RenameField',
#  'RenameMetatag',
#  'ReplaceAction',
#  'ReplaceFont',
#  'Revision',
#  'Run',
#  'RunScriptMacro',
#  'Save',
#  'SaveAs',
#  'ScanFont',
#  'SelectText',
#  'SelectionMode',
#  'SetBarCodeImage',
#  'SetCurFieldName',
#  'SetCurMetatagName',
#  'SetDRMAuthority',
#  'SetFieldViewOption',
#  'SetMessageBoxMode',
#  'SetPos',
#  'SetPosBySet',
#  'SetPrivateInfoPassword',
#  'SetTextFile',
#  'SetTitleName',
#  'SetUserInfo',
#  'SideType',
#  'Signature',
#  'Slash',
#  'SolarToLunar',
#  'SolarToLunarBySet',
#  'SortDelimiter',
#  'StrikeOut',
#  'StyleType',
#  'SubtPos',
#  'TableBreak',
#  'TableFormat',
#  'TableSwapType',
#  'TableTarget',
#  'TextAlign',
#  'TextArtAlign',
#  'TextDir',
#  'TextFlowType',
#  'TextWrapType',
#  'UnSelectCtrl',
#  'VAlign',
#  'Version',
#  'VertRel',
#  'ViewFlag',
#  'ViewProperties',
#  'WatermarkBrush',
#  'WidthRel',
#  'XHwpDocuments',
#  'XHwpMessageBox',
#  'XHwpODBC',
#  'XHwpWindows',
#  '_ApplyTypes_',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_good_object_',
#  '_get_good_single_object_',
#  '_oleobj_',
#  '_prop_map_get_',
#  '_prop_map_put_',
#  'coclass_clsid']

# %%
dir(app.api.XHwpDocuments.Active_XHwpDocument)
# Out:
# ['Application',
#  'CLSID',
#  'Clear',
#  'Close',
#  'Document',
#  'DocumentID',
#  'EditMode',
#  'Format',
#  'FullName',
#  'Modified',
#  'Open',
#  'Password',
#  'Path',
#  'Redo',
#  'Save',
#  'SaveAs',
#  'SendBrowser',
#  'SetActive_XHwpDocument',
#  'Undo',
#  'XHwpCharacterShape',
#  'XHwpDocumentInfo',
#  'XHwpFind',
#  'XHwpFormCheckButtons',
#  'XHwpFormComboBoxs',
#  'XHwpFormEdits',
#  'XHwpFormPushButtons',
#  'XHwpFormRadioButtons',
#  'XHwpParagraphShape',
#  'XHwpPrint',
#  'XHwpRange',
#  'XHwpSelection',
#  'XHwpSendMail',
#  'XHwpSummaryInfo',
#  '_ApplyTypes_',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_good_object_',
#  '_get_good_single_object_',
#  '_oleobj_',
#  '_prop_map_get_',
#  '_prop_map_put_',
#  'coclass_clsid',
#  'frame']

# %%
app.open(r"C:\Users\freed\Downloads\일반관리비 관리 자료 작성\1. Template6_일반관리비template_0309_1730(수정).hwp")
# Out:
# 'C:/Users/freed/Downloads/일반관리비 관리 자료 작성/1. Template6_일반관리비template_0309_1730(수정).hwp'
