# %% [raw]
# ---
# description: Core Classes for HwpApi
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ### gencache error 해결
#
# 캐시가 충돌하는 문제를 해결하기 위해서 장치를 마련했습니다.
# 오류가 나는지 확인은 필요할 것으로 보입니다.

# %% [markdown]
# ### 필요한 패키지는

# %% [markdown]
# App은 기존 hwpapi를 wrapping 하여 보다 사용하기 쉽게 만드는 것을 목적으로 하고 있는 클래스 입니다.
#
# 제가 만든 기능을 사용할 수 있을 뿐만 아니라 `HwpApi`
# 한글 컨트롤과 동등한 기능을 부여하고자 하였으며 api 메소드를 통해 win32com의 방식으로 모두 사용할 수 있어 다양하게 사용할 수 있습니다.
# 기본 메소드를 보다 쓰기 쉽게 만들고자 합니다.
# 앞으로 추가할 기능은 화면 크기 조정 등이 있습니다.

# %% [markdown]
# 기본적으로는 [`App`](https://JunDamin.github.io/HwpApi/core.html#app) 클래스와 [`_Action`](https://JunDamin.github.io/HwpApi/actions.html#_action)클래스가 있습니다.
# [`_Action`](https://JunDamin.github.io/HwpApi/actions.html#_action) 클래스는 [`App`](https://JunDamin.github.io/HwpApi/core.html#app)로만 생성되어야 하기 때문에 언더바로 시작합니다.

# %%
#| echo: false
#| output: asis
show_doc(App)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L17){target="_blank" style="float:right; font-size:smaller"}
#
# ### App
#
# >      App (api=None)
#
# App 클래스는 한컴오피스의 한/글 프로그램과 상호작용하기 위한 인터페이스를 제공합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.set_visible)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L37){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.set_visible
#
# >      App.set_visible (app:__main__.App, is_visible=True, window_i=0)
#
# `set_visible()` 함수는 한/글 프로그램의 창을 화면에 보이거나 숨기기 위해 호출됩니다.
# `is_visible` 인자가 `True`일 경우 창이 화면에 보이고, `False`일 경우 숨깁니다.
# `window_i` 인자는 창의 인덱스를 지정합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.get_filepath)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L46){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.get_filepath
#
# >      App.get_filepath (app:__main__.App)
#
# `get_filepath()` 함수는 현재 열려있는 한/글 문서의 경로를 반환합니다.

# %%
import pywintypes

try:
    app = App(app.api)
except NameError:
    app = App()
except pywintypes.com_error:
    app = App()

# %%
#| echo: false
#| output: asis
show_doc(App.open)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L53){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.open
#
# >      App.open (app:__main__.App, path:str)
#
# `open()` 함수는 파일 경로를 인자로 받아 해당 파일을 한/글 프로그램에서 엽니다.
# `get_absolute_path()` 함수를 호출하여 절대 경로로 변환한 후, `api.Open()` 함수를 호출하여 파일을 엽니다.
# 열린 파일의 경로를 반환합니다.

# %%
app.open(r"C:\Users\freed\Downloads\일반관리비 관리 자료 작성\1. Template6_일반관리비template_0309_1730(수정).hwp")
# Out:
# 'C:/Users/freed/Downloads/일반관리비 관리 자료 작성/1. Template6_일반관리비template_0309_1730(수정).hwp'

# %%
#| echo: false
#| output: asis
show_doc(App.save)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L63){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.save
#
# >      App.save (app:__main__.App, path=None)
#
# `save()` 함수는 현재 열려있는 문서를 저장하거나 다른 이름으로 저장합니다.
# `path` 인자가 주어지지 않은 경우 현재 문서를 덮어쓰기로 저장하고, 저장된 파일의 경로를 반환합니다.
# `path` 인자가 주어진 경우, `Path` 모듈을 이용하여 파일 확장자를 추출한 후, 해당 확장자에 맞게 문서를 저장합니다.
# 저장된 파일의 경로를 반환합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.close)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L81){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.close
#
# >      App.close (app:__main__.App)
#
# `close()` 함수는 현재 열려있는 문서를 닫습니다.

# %%
#| echo: false
#| output: asis
show_doc(App.quit)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L87){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.quit
#
# >      App.quit (app:__main__.App)
#
# `quit()` 함수는 한/글 프로그램을 종료합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.create_action)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L93){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.create_action
#
# >      App.create_action (app:__main__.App, action_key:str)
#
# `create_action()` 함수는 `_Action` 클래스의 객체를 생성하여 반환합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.create_parameterset)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L99){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.create_parameterset
#
# >      App.create_parameterset (app:__main__.App, action_key:str)
#
# `create_parameterset()` 함수는 특정 액션의 파라미터셋을 반환합니다.
# `_action_info` 딕셔너리에서 액션에 대한 정보를 찾아서 파라미터셋의 키 값을 가져옵니다. 파라미터셋 객체를 반환합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.insert_text)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/methods.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.insert_text
#
# >      App.insert_text (app:__main__.App, text:str)
#
# `text를 입력합니다.

# %%
app.insert_text("test")
# Out:
# True

# %%
#| echo: false
#| output: asis
show_doc(App.find_files)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L119){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.find_files
#
# >      App.find_files (app:__main__.App)
#
# `text를 입력합니다.

# %%
#| echo: false
#| output: asis
show_doc(App.scan)
# Out:
# ---
#
# ### scan
#
# >      scan (app:__main__.App, option='All', selection=False,
# >            scan_spos='Document', scan_epos='Document', spara=None, spos=None,
# >            epara=None, epos=None, scan_direction='Forward')

# %%
#| echo: false
#| output: asis
show_doc(App.move)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L232){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.move
#
# >      App.move (app:__main__.App, move_key='ScanPos', para=None, pos=None)
#
# 키워드를 바탕으로 캐럿 위치를 이동시킵니다.

# %%
get_value(move_ids, "ScanPos")
# Out:
# 201

# %%
with app.scan() as scan:
    for text in scan:
        print(text)
        if "청년인턴" in text:
            app.move()
# Out:
# (6) 일반관리비 관리 지표의 점수계산을 위한 Template(2)_준정부기관
#
#  준정부기관은 이 양식을 사용하는 것을 원칙으로 하며, 자체수익사업 등이 있는 기관의 경우에는 양식 (5)를 사용할 수 있음.
#
#
#
#
# 구분
#
# 2022
#
# 2021
#
# 2020
#
# 1. 사업비(직접사업비와 사업비성 경비)와 판관비(또는 경비)
#
#
#
#
#
#
#
#   a. 손익계산서 등의 직접사업비<주1>
#
# 968,356,150,820
#
# 844,717,571,019
#
# 743,960,305,518
#
#   b. 손익계산서 등의 사업비성 경비<주1>
#
# -
#
# -
#
# -
#
#   c. 손익계산서상의 판관비(또는 경비)
#
# 52,823,138,260
#
# 45,739,033,709
#
# 44,912,084,147
#
#  사업비와 판관비 계: (A)=a+b+c
#
# 1,021,179,289,080
#
# 890,456,604,728
#
# 788,872,389,665
#
# 2. 사업비 중 제외항목 <주2>
#
#
#
#
#
#
#
#   d. 직접사업비
#
# 938,474,753,330
#
# 820,516,672,451
#
# 708,180,239,253
#
#   e. 사업비성 경비
#
# 8,976,588,028
#
# 6,289,073,570
#
# 10,647,673,873
#
# 제외항목 총계: (B)=d+e
#
# 947,451,341,358
#
# 826,805,746,021
#
# 718,827,913,126
#
# 3. 비정규직 인건비 등 <주3>
#
#
#
#
#
#
#
#
#   f. 비정규직 인건비 등 총계
#
# 19,442,425,086
#
# 17,243,943,642
#
# 19,856,530,881
#
#
#   g. 비정규직 특수건강진단비
#
# -
#
# -
#
# -
#
#
# 차감 비정규직 인건비 등: (C) = f-g
#
# 19,442,425,086
#
# 17,243,943,642
#
# 19,856,530,881
#
# 4. 비상임이사 인건비(D)<주4>
#
# 61,300,000
#
# 76,549,990
#
# 63,850,000
#
# 5. 인상률 제외 인건비 중 기타 제외 인건비(E) <주5>
#
#
#
# -
#
# -
#
# 6. 사내근로복지기금출연금(F) <주6>
#
#
#
# -
#
# -
#
# 7. 감가상각비
#
#
#
#
#
#
#
#   h. 사업비로 처리된 유형자산 감가상각비
#
# 439,207,413
#
# 496,001,763
#
# 509,099,787
#
#   i. 사업비로 처리된 무형자산 감가상각비
#
# -
#
# -
#
# -
#
#   j. 판관비로 처리된 유형자산 감가상각비
#
# 8,563,565,655
#
# 8,245,421,190
#
# 8,453,899,310
#
#   k. 판관비로 처리된 무형자산 감가상각비
#
# 2,937,462,955
#
# 2,721,623,724
#
# 2,551,321,675
#
# 감가상각비 총계: (G) = h+i+j+k
#
# 11,940,236,023
#
# 11,463,046,677
#
# 11,514,320,772
#
# 8. 교육훈련비 <주7>
#
#
#
#
#
#
#
#   l. 사업비로 처리된 교육훈련비
#
# 1,430,893
#
# 38,828,940
#
# 60,983,811
#
#   m. 판관비로 처리된 교육훈련비
#
# 1,450,057,354
#
# 1,360,002,485
#
# 1,263,153,190
#
# 교육훈련비 총계: (H) =l+m
#
# 1,451,488,247
#
# 1,398,831,425
#
# 1,324,137,001
#
# 9. 연구비 및 경상개발비 <주7>
#
#
#
#
#
#
#
#   n. 사업비로 처리된 연구비 및 경상개발비
#
# -
#
# -
#
# -
#
#   o. 판관비로 처리된 연구비 및 경상개발비
#
# 373,155,890
#
# 323,413,809
#
# 122,238,417
#
# 연구비 및 경상개발비 총계: (I) = n+o
#
# 373,155,890
#
# 323,413,809
#
# 122,238,417
#
# 10. 세금과공과 <주7, 8>
#
#
#
#
#
#
#
#   p. 사업비로 처리된 세금과공과
#
# -
#
# -
#
# -
#
#   q. 판관비로 처리된 세금과공과
#
# 721,630,836
#
# 647,281,606
#
# 542,776,456
#
# 세금과공과 총계: (J) = p+q
#
# 721,630,836
#
# 647,281,606
#
# 542,776,456
#
# 11. 수선유지비 <주7, 9>
#
#
#
#
#
#
#
#   r. 사업비로 처리된 수선유지비
#
#
#
#
#
#
#
#   s. 판관비로 처리된 수선유지비
#
#
#
#
#
#
#
# 세금과공과 총계: (K) = r+s
#
# -
#
# -
#
# -
#
#
# 일반관리비:
#
# (L)=(A)-(B)+(C)+(D)+(E)+(F)-(G)-(H)-(I)-(J)-(K)
#
# 78,745,161,812
#
# 67,138,778,822
#
# 76,461,384,774
#
# 매출액: (M)
#
# 1,082,748,153,681
#
# 943,261,080,451
#
# 842,716,245,593
#
# 일반관리비 관리 지표 = (L)/(M)
#
# 7.273%
#
# 7.118%
#
# 9.073test%
#
#
#
#
#
# * 청년인턴이 무기계약직으로 전환된 경우 비교가능성 등 동질성이 유지되도록 전년도 일반관리비 계산 시 당년도에 전환된 무기계약직 인건비 발생액을 전년도 일반관리비에 가산하여 기준치를 조정한 후 일반관리비 관리 점수계산을 할 수 있음

# %%
@patch
def setup_page(
    app:App,   # app
    top=20,     # 윗 여백
    bottom=10,     # 아래 여백
    right=20,     # 오른쪽 여백
    left=20,     # 왼쪽 여백
    header=15,     # 머릿말
    footer=5,     # 꼬릿말
    gutter=0):    # 제본
    """
    페이지를 설정합니다.
    """
    action = app.actions.PageSetup()
    p = action.pset

    p.PageDef.TopMargin = app.api.MiliToHwpUnit(top)
    p.PageDef.HeaderLen = app.api.MiliToHwpUnit(header)
    p.PageDef.RightMargin = app.api.MiliToHwpUnit(right)
    p.PageDef.BottomMargin = app.api.MiliToHwpUnit(bottom)
    p.PageDef.FooterLen = app.api.MiliToHwpUnit(footer)
    p.PageDef.LeftMargin = app.api.MiliToHwpUnit(left)
    p.PageDef.GutterLen = app.api.MiliToHwpUnit(gutter)
    
    return action.run()

# %%
#| echo: false
#| output: asis
show_doc(App.insert_picture)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L254){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.insert_picture
#
# >      App.insert_picture (app:__main__.App, fpath, width=None, height=None,
# >                          size_option='realSize', reverse=False,
# >                          watermark=False, effect='RealPicture')
#
# 사이즈를 지정하여 사진 삽입
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | app | App |  | app |
# | fpath |  |  | 그림 위치 |
# | width | NoneType | None | 넓이 |
# | height | NoneType | None | 높이 |
# | size_option | str | realSize | 사이즈 옵션 |
# | reverse | bool | False | 이미지 반전 여부 |
# | watermark | bool | False | 워커마크 여부 |
# | effect | str | RealPicture | 화면 효과 |

# %%
#| echo: false
#| output: asis
show_doc(App.get_selected_text)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L282){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.get_selected_text
#
# >      App.get_selected_text (app:__main__.App)
#
# 선택된 영역의 텍스트를 불러온다.

# %%
#| echo: false
#| output: asis
show_doc(App.replace_all)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L299){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.replace_all
#
# >      App.replace_all (app:__main__.App, old='', new='', old_fontcolor=None,
# >                       new_fontcolor=None, old_fontsize=None,
# >                       new_fontsize=None, old_fontname='', old_fonttype=1,
# >                       new_fontname='', new_fonttype=1, old_fontratio=None,
# >                       new_fontratio=None, old_spacing=None, new_spacing=None,
# >                       old_bold=None, new_bold=None, old_italic=None,
# >                       new_italic=None, old_underline=None, new_underline=None,
# >                       old_strike_out=None, new_strike_out=None,
# >                       ignore_message=True, direction='All', match_case=False,
# >                       all_word_forms=False, several_words=False,
# >                       use_wild_cards=False, whole_word_only=False,
# >                       auto_spell=True, replace_mode=True,
# >                       ignore_find_string=False, ignore_replace_string=False,
# >                       find_style='', replace_style='', find_jaso=False,
# >                       find_reg_exp=False, find_type=True)
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | app | App |  |  |
# | old | str |  |  |
# | new | str |  |  |
# | old_fontcolor | NoneType | None | 찾을 폰트 색 |
# | new_fontcolor | NoneType | None | 바꿀 폰트 색 |
# | old_fontsize | NoneType | None | 찾을 폰트 크기(height) |
# | new_fontsize | NoneType | None | 바꿀 폰트 크기(height) |
# | old_fontname | str |  | 찾을 글꼴 |
# | old_fonttype | int | 1 | 찾을 글꼴 타입 TTF = 1, HTF = 2 |
# | new_fontname | str |  | 바꿀 글꼴 |
# | new_fonttype | int | 1 | 바꿀 글꼴 타입 TTF = 1, HTF = 2 |
# | old_fontratio | NoneType | None | 찾을 장평 |
# | new_fontratio | NoneType | None | 바꿀 장평 |
# | old_spacing | NoneType | None | 찾을 자간 |
# | new_spacing | NoneType | None | 바꿀 자간 |
# | old_bold | NoneType | None | 찾을 볼드 |
# | new_bold | NoneType | None | 바꿀 볼드 |
# | old_italic | NoneType | None | 찾을 이텔릭 |
# | new_italic | NoneType | None | 바꿀 이텔릭 |
# | old_underline | NoneType | None | 찾을 밑줄 |
# | new_underline | NoneType | None | 바꿀 밑줄 |
# | old_strike_out | NoneType | None | 찾을 취소선 |
# | new_strike_out | NoneType | None | 바꿀 취소선 |
# | ignore_message | bool | True | 메시지 무시 여부 |
# | direction | str | All | 찾을 방향 |
# | match_case | bool | False | 대소문자 구분 |
# | all_word_forms | bool | False | 문자열 결합 |
# | several_words | bool | False | 여러 단어 찾기 |
# | use_wild_cards | bool | False | 아무개 문자 |
# | whole_word_only | bool | False | 온전한 낱말 |
# | auto_spell | bool | True | 토시 자동 교정 |
# | replace_mode | bool | True | 찾아 바꾸기 모드 |
# | ignore_find_string | bool | False | 찾을 문자열 무시 |
# | ignore_replace_string | bool | False | 바꿀 문자열 무시 |
# | find_style | str |  | 찾을 스타일 |
# | replace_style | str |  | 바꿀 스타일 |
# | find_jaso | bool | False | 자소로 찾기 |
# | find_reg_exp | bool | False | 정규표현식으로 찾기 |
# | find_type | bool | True | 다시 찾기를 할 때 마지막으로 실한 찾기를 할 경우 True, 찾아가기를 할경우 False |

# %%
app.replace_all("t", "txt", new_fontname="가는안상수체", new_fontsize=21, new_fonttype=1)
# Out:
# False

# %%
app.replace_all("", "", old_fontname="바탕체", new_fontname="바탕체", ignore_find_string=True, ignore_replace_string=True, new_fontsize=11, new_fonttype=1)
# Out:
# False

# %%
#| echo: false
#| output: asis
show_doc(App.insert_file)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/core.py#L372){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.insert_file
#
# >      App.insert_file (app:__main__.App, fpath, keep_charshape=False,
# >                       keep_parashape=False, keep_section=False,
# >                       keep_style=False)
#
# 파일 끼워 넣기

# %% [markdown]
# 한글 문서 사용은 다음과 같이 할 수 있습니다.
# 먼저 App 객체를 생성합니다.

# %%
app.get_selected_text()
# Out:
# '연구비 및 경상개발비 총계: (I) = n+o\n'

# %%
p = app.actions.InsertFile().pset

# %%
dir(p)
# Out:
# ['CLSID',
#  'CreateItemArray',
#  'FileArg',
#  'FileFormat',
#  'HSet',
#  'KeepCharshape',
#  'KeepParashape',
#  'KeepSection',
#  'KeepStyle',
#  '_ApplyTypes_',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_good_object_',
#  '_get_good_single_object_',
#  '_oleobj_',
#  '_prop_map_get_',
#  '_prop_map_put_',
#  'coclass_clsid',
#  'filename']
