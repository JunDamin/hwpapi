# %% [markdown]
# ---
# description: App Methods for HwpApi
# output-file: methods.html
# title: methods
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(App.insert_text)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/methods.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### App.insert_text
#
# >      App.insert_text (app:HwpApi.core.App, text:str)
#
# `text를 입력합니다.
