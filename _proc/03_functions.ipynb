# %% [markdown]
# ---
# description: action list
# output-file: fnctions.html
# title: functions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(get_absolute_path)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/functions.py#L9){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_absolute_path
#
# >      get_absolute_path (path)

# %%
#| echo: false
#| output: asis
show_doc(get_dll_path)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/functions.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_dll_path
#
# >      get_dll_path (package_name, dll_filename)

# %%
#| echo: false
#| output: asis
show_doc(get_registry_value)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/functions.py#L44){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_registry_value
#
# >      get_registry_value (key_path, value_name)

# %%
#| echo: false
#| output: asis
show_doc(add_dll_to_registry)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/functions.py#L29){target="_blank" style="float:right; font-size:smaller"}
#
# ### add_dll_to_registry
#
# >      add_dll_to_registry (dll_path, key_path)

# %%
#| echo: false
#| output: asis
show_doc(check_dll)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/functions.py#L54){target="_blank" style="float:right; font-size:smaller"}
#
# ### check_dll
#
# >      check_dll ()

# %%
#| echo: false
#| output: asis
show_doc(get_value)
# Out:
# ---
#
# [source](https://github.com/JunDamin/HwpApi/blob/main/HwpApi/functions.py#L67){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_value
#
# >      get_value (dict_, key)

# %%
#| echo: false
#| output: asis
show_doc(set_charshape)
# Out:
# ---
#
# ### set_charshape
#
# >      set_charshape (charshape, fontname:str, font_type:int, fontcolor,
# >                     fontsize:int, bold:bool, intalic:bool, strike_out,
# >                     under_line, fontratio)
